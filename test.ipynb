# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = ['SimHei']
x = np.array([1, 2, 3, 4, 5])
y = np.array([5, 4, 3, 2, 1])
fig, axes = plt.subplots(1, 2, figsize=(6, 4), dpi=200)
ax =  axes[0]
sns.scatterplot(
    data=pd.DataFrame({'x': x, 'y': y}),
    x='x',
    y='y',
    size="x",
    ax=ax
)
ax.annotate(
    '最大值',
    xy=(max(x), max(y)),
    xytext=(max(x)-1, max(y)+0.5),
    fontsize=8,
    arrowprops=dict(arrowstyle='->', lw=0.5)
)
ax.axhline(y=np.mean(y), color='r', linestyle='--', lw=0.5)
ax.axvline(x=np.mean(x), color='b', linestyle='--', lw=0.5)
ax = axes[1]
sns.lineplot(
    pd.DataFrame({'x': x, 'y': y}),
    x='x',
    y='y',
    label='y轴',
    err_style="band",
)
ax.axvspan(xmin=2, xmax=4, color='gray', alpha=0.3)# 添加阴影区域
ax.axhspan(ymin=2, ymax=4, color='yellow', alpha=0.3)# 添加阴影区域
plt.show()

# %%
import seaborn as sns
import matplotlib.pyplot as plt

fmri = sns.load_dataset("fmri")
sns.lineplot(
    data=fmri, 
    x="timepoint", 
    y="signal", 
    hue="event",     # 'event' 控制颜色
    units="subject", # 'subject' 控制“谁”是一条线
    estimator=None   # 关键：我们不想要平均线了，只看个体
)
plt.title("Using hue + units + estimator=None (Individual Lines)")
plt.show()
# Out:
# d:\conda_envs\syc\Lib\site-packages\IPython\core\pylabtools.py:170: UserWarning: Glyph 8722 (\N{MINUS SIGN}) missing from font(s) SimHei.
#   fig.canvas.print_figure(bytes_io, **kw)

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

plt.rcParams['font.family'] = ['SimHei']
x = np.array([1, 2, 3, 4, 5])
y = np.array([5, 4, 3, 2, 1])
rel = sns.relplot(
    pd.DataFrame({'x': x, 'y': y}),
    x='x',
    y='y',
    kind='scatter',
)
plt.setp(rel.ax.xaxis.get_majorticklabels(), rotation=45) # ⚠️X轴标签:45度旋转(日期不重叠)""
plt.show()
sns.violinplot(
    pd.DataFrame({'x': x, 'y': y}),
    x='x',
    y='y',
    inner='point'
)
plt.suptitle("小提琴图")
# Out:
# Text(0.5, 0.98, '小提琴图')

# %%
import pandas as pd
import numpy as np
df = pd.DataFrame(np.random.randn(10, 4), columns=list('ABCD'))
df.reset_index()
df
# Out:
#           A         B         C         D
# 0 -0.865504 -0.168716 -1.175776 -1.383273
# 1  0.874353 -0.773671  0.370917  1.252261
# 2 -0.507200 -0.362979 -0.276064 -1.058025
# 3  0.663713 -0.536019 -0.839662 -0.893686
# 4  1.569076  0.115903 -0.324122  0.628751
# 5  0.299900 -2.184306 -1.489516  0.225526
# 6  0.684689  0.375454  0.315187 -0.414078
# 7  1.338831  0.875517 -0.106462  0.466148
# 8  1.029595  1.061080  0.563748  1.129819
# 9 -0.243326  0.679642 -0.168270  1.376160
